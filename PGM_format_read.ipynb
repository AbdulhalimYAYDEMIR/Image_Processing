# %%
# Abdülhalim YAYDEMİR

# %%
#test.pgm dosyası 'rb' modunda açılarak okundu.
with open("test.pgm", "rb") as fileObject:
    fileContent=fileObject.read()
    print('Dosya içeriği(direkt yazdırma) :\n')
    print(fileContent)  
    print()
    
    
    

    #dosyanın ilk iki karakterine bakılarak P5 formatı olup olmadığına bakıldı sonra alt satıra geçildi.
    print('Dosya içeriği(bakarak yazdırma) :\n')
    i=0
    while fileContent[i]!=10:
        if i==0:
            if (fileContent[0]==80) & (fileContent[1]==53):
                print('P5 pgm formatı')  
            else:
                print('P5 pgm formatı değil')
        i=i+1

    i=i+1
    
    
    
    
    
    # '#' ile başlayan satır geçildi.
    while fileContent[i]!=10:
        if fileContent[i]==35:
            while fileContent[i]!=10:
                i=i+1
    i=i+1
    
    
    
    
    
    # genişlik yükseklik bilgileri yazdırıldı alt satıra geçildi.
    while fileContent[i]!=10:
        if fileContent[i]==35:
            while fileContent[i]!=10:
                i=i+1  
        else:
            while fileContent[i]!=32:
                width=chr(fileContent[i])
                width=int(width)
                print(width,end="")
                i=i+1
            i=i+1
            print(end=" ")
            while fileContent[i]!=10:
                height=chr(fileContent[i])
                height=int(height)
                print(height,end="")
                i=i+1
            print()
                   
    i=i+1
             
            
            
            
            
    # maxval değeri yazdırılıp alt satıra geçildi.
    while fileContent[i]!=10:
        maxval=chr(fileContent[i])
        print(maxval,end="")
        i=i+1
    
    i=i+1
    
    
    
    
    
    # piksel değerleri yazdırıldı.
    j=1
    print()
    while fileContent[i]!=80:          # fileContent devam ettirilince başa döndüğü farkedildi bu yüzden 'P' karakteri gelince while'dan çıkıldı.
        print(j,'. index ',fileContent[i])
        i=i+1
        j=j+1
        if j==10:
            break
# Out:
# Dosya içeriği(direkt yazdırma) :
#
# b'P5\n# test.pgm\n3 3\n255\nefghijklm'
#
# Dosya içeriği(bakarak yazdırma) :
#
# P5 pgm formatı
# 3 3
# 255
# 1 . index  101
# 2 . index  102
# 3 . index  103
# 4 . index  104
# 5 . index  105
# 6 . index  106
# 7 . index  107
# 8 . index  108
# 9 . index  109
